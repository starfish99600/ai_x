# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %%
# import
import numpy as np
import pandas as pd # 원핫인코딩
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras.models import Sequential, load_model, save_model 
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt # 학습과정 시각화

# %%
# 데이터생성 및 전처리(라벨인코딩만 하고 원핫인코딩 X)

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %% [markdown]
# # 1. 기본적인 DNN(원핫인코딩X)

# %%
# 모델 설정
# model = Sequential()
# model.add(Input(4,))
# model.add(Dense(units=50, activation='relu'))
# model.add(Dense(units=30, activation='relu'))
# model.add(Dense(units=3, activation='softmax'))
model = Sequential([
    Input(4,),
    Dense(units=50, activation='relu'),
    Dense(units=30, activation='relu'),
    Dense(units=3, activation='softmax'),
])
model.summary() # 250+1530+93 = 1837개 파라미터
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 50)                250
#
#  dense_7 (Dense)             (None, 30)                1530
#
#  dense_8 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습설정
model.compile(loss='sparse_categorical_crossentropy', # 라벨인코딩만 되어 있는경우
             optimizer='adam',
             metrics=['accuracy'])
# 학습
earlyStropping = EarlyStopping(patience=50) # monitor='val_loss' 기본값
hist = model.fit(train_X, train_y, epochs=1000,
                validation_split=0.2,
                callbacks=[earlyStropping])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 1s 58ms/step - loss: 1.1607 - accuracy: 0.2593 - val_loss: 0.9859 - val_accuracy: 0.3333
# Epoch 2/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.9810 - accuracy: 0.4167 - val_loss: 0.9711 - val_accuracy: 0.2222
# Epoch 3/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9100 - accuracy: 0.3611 - val_loss: 0.9622 - val_accuracy: 0.2222
# Epoch 4/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8858 - accuracy: 0.3981 - val_loss: 0.9289 - val_accuracy: 0.5926
# Epoch 5/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8592 - accuracy: 0.6111 - val_loss: 0.8762 - val_accuracy: 0.7037
# Epoch 6/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8282 - accuracy: 0.6481 - val_loss: 0.8212 - val_accuracy: 0.7037
# Epoch 7/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8015 - accuracy: 0.6667 - val_loss: 0.7848 - val_accuracy: 0.7407
# Epoch 8/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7814 - accuracy: 0.7037 - val_loss: 0.7585 - val_accuracy: 0.8148
# Epoch 9/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7618 - accuracy: 0.7130 - val_loss: 0.7352 - val_accuracy: 0.7407
# Epoch 10/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7403 - accuracy: 0.7130 - val_loss: 0.7150 - val_accuracy: 0.8148
# Epoch 11/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7207 - accuracy: 0.7685 - val_loss: 0.6910 - val_accuracy: 0.8148
# Epoch 12/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7040 - accuracy: 0.8426 - val_loss: 0.6660 - val_accuracy: 0.8519
# Epoch 13/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6854 - accuracy: 0.8148 - val_loss: 0.6436 - val_accuracy: 0.8148
# Epoch 14/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6649 - accuracy: 0.7130 - val_loss: 0.6234 - val_accuracy: 0.7037
# Epoch 15/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6493 - accuracy: 0.6852 - val_loss: 0.6079 - val_accuracy: 0.7037
# Epoch 16/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6310 - accuracy: 0.6759 - val_loss: 0.5871 - val_accuracy: 0.7037
# Epoch 17/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6153 - accuracy: 0.7037 - val_loss: 0.5643 - val_accuracy: 0.7778
# Epoch 18/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6000 - accuracy: 0.7870 - val_loss: 0.5472 - val_accuracy: 0.8148
# Epoch 19/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5833 - accuracy: 0.7593 - val_loss: 0.5285 - val_accuracy: 0.7037
# Epoch 20/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5682 - accuracy: 0.6852 - val_loss: 0.5187 - val_accuracy: 0.7037
# Epoch 21/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5527 - accuracy: 0.6944 - val_loss: 0.4945 - val_accuracy: 0.7778
# Epoch 22/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5371 - accuracy: 0.8056 - val_loss: 0.4728 - val_accuracy: 0.8889
# Epoch 23/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5253 - accuracy: 0.8611 - val_loss: 0.4576 - val_accuracy: 0.8889
# Epoch 24/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5146 - accuracy: 0.8981 - val_loss: 0.4450 - val_accuracy: 0.8889
# Epoch 25/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5015 - accuracy: 0.8519 - val_loss: 0.4369 - val_accuracy: 0.8148
# Epoch 26/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4900 - accuracy: 0.8426 - val_loss: 0.4257 - val_accuracy: 0.8148
# Epoch 27/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4793 - accuracy: 0.8426 - val_loss: 0.4162 - val_accuracy: 0.8519
# Epoch 28/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4699 - accuracy: 0.8519 - val_loss: 0.4041 - val_accuracy: 0.8889
# Epoch 29/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4590 - accuracy: 0.8611 - val_loss: 0.3952 - val_accuracy: 0.8889
# Epoch 30/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4493 - accuracy: 0.8981 - val_loss: 0.3815 - val_accuracy: 0.9630
# Epoch 31/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4413 - accuracy: 0.9630 - val_loss: 0.3698 - val_accuracy: 0.9630
# Epoch 32/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4309 - accuracy: 0.9444 - val_loss: 0.3648 - val_accuracy: 0.9259
# Epoch 33/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4226 - accuracy: 0.8981 - val_loss: 0.3591 - val_accuracy: 0.9259
# Epoch 34/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4124 - accuracy: 0.9167 - val_loss: 0.3438 - val_accuracy: 0.9630
# Epoch 35/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4036 - accuracy: 0.9722 - val_loss: 0.3329 - val_accuracy: 0.9630
# Epoch 36/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3976 - accuracy: 0.9815 - val_loss: 0.3266 - val_accuracy: 0.9630
# Epoch 37/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3848 - accuracy: 0.9630 - val_loss: 0.3305 - val_accuracy: 0.9259
# Epoch 38/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3799 - accuracy: 0.8981 - val_loss: 0.3257 - val_accuracy: 0.9259
# Epoch 39/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3709 - accuracy: 0.9074 - val_loss: 0.3142 - val_accuracy: 0.9259
# Epoch 40/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3609 - accuracy: 0.9444 - val_loss: 0.3020 - val_accuracy: 0.9630
# Epoch 41/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3516 - accuracy: 0.9537 - val_loss: 0.2922 - val_accuracy: 0.9630
# Epoch 42/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3432 - accuracy: 0.9630 - val_loss: 0.2830 - val_accuracy: 0.9630
# Epoch 43/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3382 - accuracy: 0.9722 - val_loss: 0.2773 - val_accuracy: 0.9630
# Epoch 44/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3279 - accuracy: 0.9815 - val_loss: 0.2661 - val_accuracy: 1.0000
# Epoch 45/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3231 - accuracy: 0.9815 - val_loss: 0.2636 - val_accuracy: 0.9630
# Epoch 46/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3147 - accuracy: 0.9630 - val_loss: 0.2673 - val_accuracy: 0.9630
# Epoch 47/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3054 - accuracy: 0.9537 - val_loss: 0.2577 - val_accuracy: 0.9630
# Epoch 48/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2974 - accuracy: 0.9722 - val_loss: 0.2466 - val_accuracy: 0.9630
# Epoch 49/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2919 - accuracy: 0.9815 - val_loss: 0.2385 - val_accuracy: 0.9630
# Epoch 50/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2890 - accuracy: 0.9630 - val_loss: 0.2425 - val_accuracy: 0.9630
# Epoch 51/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2775 - accuracy: 0.9630 - val_loss: 0.2332 - val_accuracy: 0.9630
# Epoch 52/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2707 - accuracy: 0.9722 - val_loss: 0.2260 - val_accuracy: 0.9630
# Epoch 53/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2644 - accuracy: 0.9722 - val_loss: 0.2235 - val_accuracy: 0.9630
# Epoch 54/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2576 - accuracy: 0.9722 - val_loss: 0.2163 - val_accuracy: 0.9630
# Epoch 55/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2516 - accuracy: 0.9722 - val_loss: 0.2140 - val_accuracy: 0.9630
# Epoch 56/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2461 - accuracy: 0.9815 - val_loss: 0.2075 - val_accuracy: 0.9630
# Epoch 57/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2405 - accuracy: 0.9630 - val_loss: 0.2114 - val_accuracy: 0.9630
# Epoch 58/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2343 - accuracy: 0.9537 - val_loss: 0.2003 - val_accuracy: 0.9630
# Epoch 59/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2274 - accuracy: 0.9722 - val_loss: 0.1889 - val_accuracy: 0.9630
# Epoch 60/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2198 - accuracy: 0.9815 - val_loss: 0.1911 - val_accuracy: 0.9630
# Epoch 61/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2149 - accuracy: 0.9537 - val_loss: 0.1859 - val_accuracy: 0.9630
# Epoch 62/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2048 - accuracy: 0.9815 - val_loss: 0.1739 - val_accuracy: 0.9630
# Epoch 63/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2098 - accuracy: 0.9907 - val_loss: 0.1695 - val_accuracy: 0.9630
# Epoch 64/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1957 - accuracy: 0.9907 - val_loss: 0.1760 - val_accuracy: 0.9630
# Epoch 65/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1917 - accuracy: 0.9630 - val_loss: 0.1759 - val_accuracy: 0.9630
# Epoch 66/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1887 - accuracy: 0.9722 - val_loss: 0.1636 - val_accuracy: 0.9630
# Epoch 67/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1805 - accuracy: 0.9815 - val_loss: 0.1601 - val_accuracy: 0.9630
# Epoch 68/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1772 - accuracy: 0.9815 - val_loss: 0.1638 - val_accuracy: 0.9630
# Epoch 69/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1740 - accuracy: 0.9722 - val_loss: 0.1548 - val_accuracy: 0.9630
# Epoch 70/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1674 - accuracy: 0.9815 - val_loss: 0.1482 - val_accuracy: 0.9630
# Epoch 71/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1649 - accuracy: 0.9907 - val_loss: 0.1448 - val_accuracy: 0.9630
# Epoch 72/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1584 - accuracy: 0.9907 - val_loss: 0.1496 - val_accuracy: 0.9630
# Epoch 73/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1611 - accuracy: 0.9630 - val_loss: 0.1491 - val_accuracy: 0.9630
# Epoch 74/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1517 - accuracy: 0.9907 - val_loss: 0.1354 - val_accuracy: 0.9259
# Epoch 75/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1552 - accuracy: 0.9907 - val_loss: 0.1331 - val_accuracy: 0.9259
# Epoch 76/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1510 - accuracy: 0.9907 - val_loss: 0.1332 - val_accuracy: 0.9630
# Epoch 77/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1420 - accuracy: 0.9815 - val_loss: 0.1399 - val_accuracy: 0.9630
# Epoch 78/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1455 - accuracy: 0.9537 - val_loss: 0.1419 - val_accuracy: 0.9630
# Epoch 79/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1388 - accuracy: 0.9815 - val_loss: 0.1266 - val_accuracy: 0.9630
# Epoch 80/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1424 - accuracy: 0.9815 - val_loss: 0.1241 - val_accuracy: 0.9259
# Epoch 81/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1374 - accuracy: 0.9907 - val_loss: 0.1312 - val_accuracy: 0.9630
# Epoch 82/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1321 - accuracy: 0.9815 - val_loss: 0.1269 - val_accuracy: 0.9630
# Epoch 83/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1291 - accuracy: 0.9815 - val_loss: 0.1245 - val_accuracy: 0.9630
# Epoch 84/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1267 - accuracy: 0.9815 - val_loss: 0.1214 - val_accuracy: 0.9630
# Epoch 85/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1242 - accuracy: 0.9907 - val_loss: 0.1179 - val_accuracy: 0.9630
# Epoch 86/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1238 - accuracy: 0.9907 - val_loss: 0.1167 - val_accuracy: 0.9630
# Epoch 87/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1221 - accuracy: 0.9907 - val_loss: 0.1158 - val_accuracy: 0.9630
# Epoch 88/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1201 - accuracy: 0.9907 - val_loss: 0.1184 - val_accuracy: 0.9630
# Epoch 89/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1176 - accuracy: 0.9815 - val_loss: 0.1178 - val_accuracy: 0.9630
# Epoch 90/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1159 - accuracy: 0.9815 - val_loss: 0.1130 - val_accuracy: 0.9630
# Epoch 91/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1150 - accuracy: 0.9907 - val_loss: 0.1103 - val_accuracy: 0.9630
# Epoch 92/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1146 - accuracy: 0.9907 - val_loss: 0.1091 - val_accuracy: 0.9259
# Epoch 93/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1125 - accuracy: 0.9907 - val_loss: 0.1102 - val_accuracy: 0.9630
# Epoch 94/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1122 - accuracy: 0.9815 - val_loss: 0.1124 - val_accuracy: 0.9630
# Epoch 95/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1083 - accuracy: 0.9907 - val_loss: 0.1067 - val_accuracy: 0.9259
# Epoch 96/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1097 - accuracy: 0.9907 - val_loss: 0.1063 - val_accuracy: 0.9630
# Epoch 97/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1071 - accuracy: 0.9907 - val_loss: 0.1056 - val_accuracy: 0.9630
# Epoch 98/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1063 - accuracy: 0.9907 - val_loss: 0.1080 - val_accuracy: 0.9630
# Epoch 99/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1037 - accuracy: 0.9815 - val_loss: 0.1094 - val_accuracy: 0.9630
# Epoch 100/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1065 - accuracy: 0.9815 - val_loss: 0.1097 - val_accuracy: 0.9630
# Epoch 101/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1017 - accuracy: 0.9815 - val_loss: 0.1031 - val_accuracy: 0.9630
# Epoch 102/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1014 - accuracy: 0.9907 - val_loss: 0.1022 - val_accuracy: 0.9630
# Epoch 103/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1045 - accuracy: 0.9907 - val_loss: 0.1044 - val_accuracy: 0.9630
# Epoch 104/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0977 - accuracy: 0.9907 - val_loss: 0.1007 - val_accuracy: 0.9259
# Epoch 105/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1044 - accuracy: 0.9815 - val_loss: 0.0999 - val_accuracy: 0.9259
# Epoch 106/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0998 - accuracy: 0.9907 - val_loss: 0.1019 - val_accuracy: 0.9630
# Epoch 107/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0968 - accuracy: 0.9907 - val_loss: 0.1007 - val_accuracy: 0.9630
# Epoch 108/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0948 - accuracy: 0.9907 - val_loss: 0.1023 - val_accuracy: 0.9630
# Epoch 109/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0957 - accuracy: 0.9815 - val_loss: 0.1021 - val_accuracy: 0.9630
# Epoch 110/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0926 - accuracy: 0.9815 - val_loss: 0.0980 - val_accuracy: 0.9630
# Epoch 111/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0924 - accuracy: 0.9907 - val_loss: 0.0969 - val_accuracy: 0.9259
# Epoch 112/1000
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0929 - accuracy: 0.9907 - val_loss: 0.0974 - val_accuracy: 0.9630
# Epoch 113/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0926 - accuracy: 0.9815 - val_loss: 0.1016 - val_accuracy: 0.9630
# Epoch 114/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0908 - accuracy: 0.9815 - val_loss: 0.0990 - val_accuracy: 0.9630
# Epoch 115/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0891 - accuracy: 0.9907 - val_loss: 0.0975 - val_accuracy: 0.9630
# Epoch 116/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0884 - accuracy: 0.9907 - val_loss: 0.0955 - val_accuracy: 0.9630
# Epoch 117/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0897 - accuracy: 0.9907 - val_loss: 0.0984 - val_accuracy: 0.9630
# Epoch 118/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0874 - accuracy: 0.9815 - val_loss: 0.0963 - val_accuracy: 0.9630
# Epoch 119/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0858 - accuracy: 0.9907 - val_loss: 0.0940 - val_accuracy: 0.9259
# Epoch 120/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0872 - accuracy: 0.9907 - val_loss: 0.0939 - val_accuracy: 0.9630
# Epoch 121/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0847 - accuracy: 0.9907 - val_loss: 0.0974 - val_accuracy: 0.9630
# Epoch 122/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0862 - accuracy: 0.9815 - val_loss: 0.0980 - val_accuracy: 0.9630
# Epoch 123/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0874 - accuracy: 0.9815 - val_loss: 0.0950 - val_accuracy: 0.9630
# Epoch 124/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0843 - accuracy: 0.9815 - val_loss: 0.0950 - val_accuracy: 0.9259
# Epoch 125/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0931 - accuracy: 0.9815 - val_loss: 0.0922 - val_accuracy: 0.9259
# Epoch 126/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0822 - accuracy: 0.9907 - val_loss: 0.0968 - val_accuracy: 0.9630
# Epoch 127/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0859 - accuracy: 0.9815 - val_loss: 0.0990 - val_accuracy: 0.9630
# Epoch 128/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0882 - accuracy: 0.9907 - val_loss: 0.0912 - val_accuracy: 0.9259
# Epoch 129/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0835 - accuracy: 0.9815 - val_loss: 0.0908 - val_accuracy: 0.9259
# Epoch 130/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0820 - accuracy: 0.9907 - val_loss: 0.0930 - val_accuracy: 0.9630
# Epoch 131/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0805 - accuracy: 0.9907 - val_loss: 0.0907 - val_accuracy: 0.9259
# Epoch 132/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0795 - accuracy: 0.9907 - val_loss: 0.0918 - val_accuracy: 0.9630
# Epoch 133/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0785 - accuracy: 0.9907 - val_loss: 0.0936 - val_accuracy: 0.9630
# Epoch 134/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0787 - accuracy: 0.9907 - val_loss: 0.0918 - val_accuracy: 0.9630
# Epoch 135/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0788 - accuracy: 0.9907 - val_loss: 0.0896 - val_accuracy: 0.9259
# Epoch 136/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0784 - accuracy: 0.9907 - val_loss: 0.0905 - val_accuracy: 0.9630
# Epoch 137/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0768 - accuracy: 0.9907 - val_loss: 0.0908 - val_accuracy: 0.9630
# Epoch 138/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0771 - accuracy: 0.9907 - val_loss: 0.0911 - val_accuracy: 0.9630
# Epoch 139/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0758 - accuracy: 0.9907 - val_loss: 0.0888 - val_accuracy: 0.9259
# Epoch 140/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0770 - accuracy: 0.9907 - val_loss: 0.0890 - val_accuracy: 0.9259
# Epoch 141/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0792 - accuracy: 0.9907 - val_loss: 0.0960 - val_accuracy: 0.9630
# Epoch 142/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0781 - accuracy: 0.9815 - val_loss: 0.0914 - val_accuracy: 0.9630
# Epoch 143/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0776 - accuracy: 0.9907 - val_loss: 0.0880 - val_accuracy: 0.9259
# Epoch 144/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0761 - accuracy: 0.9907 - val_loss: 0.0883 - val_accuracy: 0.9259
# Epoch 145/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0785 - accuracy: 0.9907 - val_loss: 0.0939 - val_accuracy: 0.9630
# Epoch 146/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0744 - accuracy: 0.9907 - val_loss: 0.0882 - val_accuracy: 0.9259
# Epoch 147/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0730 - accuracy: 0.9815 - val_loss: 0.0905 - val_accuracy: 0.9259
# Epoch 148/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0814 - accuracy: 0.9815 - val_loss: 0.0875 - val_accuracy: 0.9259
# Epoch 149/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0717 - accuracy: 0.9907 - val_loss: 0.0912 - val_accuracy: 0.9630
# Epoch 150/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0767 - accuracy: 0.9815 - val_loss: 0.0977 - val_accuracy: 0.9630
# Epoch 151/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0750 - accuracy: 0.9815 - val_loss: 0.0879 - val_accuracy: 0.9630
# Epoch 152/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0742 - accuracy: 0.9815 - val_loss: 0.0866 - val_accuracy: 0.9259
# Epoch 153/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0705 - accuracy: 0.9907 - val_loss: 0.0902 - val_accuracy: 0.9630
# Epoch 154/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0794 - accuracy: 0.9815 - val_loss: 0.0956 - val_accuracy: 0.9630
# Epoch 155/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0701 - accuracy: 0.9907 - val_loss: 0.0863 - val_accuracy: 0.9259
# Epoch 156/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0762 - accuracy: 0.9815 - val_loss: 0.0901 - val_accuracy: 0.9259
# Epoch 157/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0792 - accuracy: 0.9815 - val_loss: 0.0860 - val_accuracy: 0.9259
# Epoch 158/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0740 - accuracy: 0.9907 - val_loss: 0.0877 - val_accuracy: 0.9630
# Epoch 159/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9259
# Epoch 160/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0703 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9259
# Epoch 161/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0703 - accuracy: 0.9907 - val_loss: 0.0860 - val_accuracy: 0.9259
# Epoch 162/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0681 - accuracy: 0.9907 - val_loss: 0.0881 - val_accuracy: 0.9630
# Epoch 163/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0720 - accuracy: 0.9907 - val_loss: 0.0882 - val_accuracy: 0.9630
# Epoch 164/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0692 - accuracy: 0.9907 - val_loss: 0.0882 - val_accuracy: 0.9259
# Epoch 165/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0763 - accuracy: 0.9815 - val_loss: 0.0857 - val_accuracy: 0.9259
# Epoch 166/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0724 - accuracy: 0.9815 - val_loss: 0.0956 - val_accuracy: 0.9630
# Epoch 167/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0819 - accuracy: 0.9815 - val_loss: 0.0960 - val_accuracy: 0.9630
# Epoch 168/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0662 - accuracy: 0.9907 - val_loss: 0.0870 - val_accuracy: 0.9259
# Epoch 169/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0886 - accuracy: 0.9722 - val_loss: 0.0967 - val_accuracy: 0.9630
# Epoch 170/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0813 - accuracy: 0.9815 - val_loss: 0.0851 - val_accuracy: 0.9259
# Epoch 171/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0671 - accuracy: 0.9907 - val_loss: 0.0961 - val_accuracy: 0.9630
# Epoch 172/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0727 - accuracy: 0.9815 - val_loss: 0.0926 - val_accuracy: 0.9630
# Epoch 173/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0686 - accuracy: 0.9907 - val_loss: 0.0851 - val_accuracy: 0.9259
# Epoch 174/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0752 - accuracy: 0.9815 - val_loss: 0.0862 - val_accuracy: 0.9259
# Epoch 175/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0654 - accuracy: 0.9907 - val_loss: 0.0884 - val_accuracy: 0.9630
# Epoch 176/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0849 - accuracy: 0.9722 - val_loss: 0.1003 - val_accuracy: 0.9630
# Epoch 177/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0719 - accuracy: 0.9907 - val_loss: 0.0856 - val_accuracy: 0.9259
# Epoch 178/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0729 - accuracy: 0.9815 - val_loss: 0.0880 - val_accuracy: 0.9259
# Epoch 179/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0699 - accuracy: 0.9815 - val_loss: 0.0856 - val_accuracy: 0.9630
# Epoch 180/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0642 - accuracy: 0.9907 - val_loss: 0.0912 - val_accuracy: 0.9630
# Epoch 181/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0678 - accuracy: 0.9907 - val_loss: 0.0873 - val_accuracy: 0.9630
# Epoch 182/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0645 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 183/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0671 - accuracy: 0.9815 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 184/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0651 - accuracy: 0.9907 - val_loss: 0.0861 - val_accuracy: 0.9630
# Epoch 185/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0649 - accuracy: 0.9907 - val_loss: 0.0877 - val_accuracy: 0.9630
# Epoch 186/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0646 - accuracy: 0.9907 - val_loss: 0.0856 - val_accuracy: 0.9630
# Epoch 187/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0649 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 188/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0635 - accuracy: 0.9907 - val_loss: 0.0847 - val_accuracy: 0.9259
# Epoch 189/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0647 - accuracy: 0.9907 - val_loss: 0.0850 - val_accuracy: 0.9259
# Epoch 190/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0656 - accuracy: 0.9907 - val_loss: 0.0874 - val_accuracy: 0.9630
# Epoch 191/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0640 - accuracy: 0.9907 - val_loss: 0.0846 - val_accuracy: 0.9259
# Epoch 192/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0634 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 193/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0660 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9259
# Epoch 194/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0638 - accuracy: 0.9815 - val_loss: 0.0852 - val_accuracy: 0.9630
# Epoch 195/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0680 - accuracy: 0.9907 - val_loss: 0.0917 - val_accuracy: 0.9630
# Epoch 196/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 197/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0652 - accuracy: 0.9815 - val_loss: 0.0857 - val_accuracy: 0.9259
# Epoch 198/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0661 - accuracy: 0.9815 - val_loss: 0.0843 - val_accuracy: 0.9259
# Epoch 199/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0650 - accuracy: 0.9907 - val_loss: 0.0866 - val_accuracy: 0.9630
# Epoch 200/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0645 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 201/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0642 - accuracy: 0.9815 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 202/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0666 - accuracy: 0.9907 - val_loss: 0.0858 - val_accuracy: 0.9630
# Epoch 203/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0624 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 204/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0628 - accuracy: 0.9907 - val_loss: 0.0857 - val_accuracy: 0.9630
# Epoch 205/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0611 - accuracy: 0.9907 - val_loss: 0.0854 - val_accuracy: 0.9630
# Epoch 206/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0623 - accuracy: 0.9907 - val_loss: 0.0840 - val_accuracy: 0.9259
# Epoch 207/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0606 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 208/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0604 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 209/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0627 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9259
# Epoch 210/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0627 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 211/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0608 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 212/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0599 - accuracy: 0.9907 - val_loss: 0.0844 - val_accuracy: 0.9259
# Epoch 213/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0603 - accuracy: 0.9907 - val_loss: 0.0863 - val_accuracy: 0.9630
# Epoch 214/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625 - accuracy: 0.9907 - val_loss: 0.0878 - val_accuracy: 0.9630
# Epoch 215/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0610 - accuracy: 0.9907 - val_loss: 0.0843 - val_accuracy: 0.9259
# Epoch 216/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0597 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 217/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 218/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0602 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9259
# Epoch 219/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0601 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 220/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0586 - accuracy: 0.9907 - val_loss: 0.0850 - val_accuracy: 0.9630
# Epoch 221/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0593 - accuracy: 0.9907 - val_loss: 0.0858 - val_accuracy: 0.9630
# Epoch 222/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0840 - val_accuracy: 0.9259
# Epoch 223/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0584 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 224/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0584 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9259
# Epoch 225/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0589 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 226/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0585 - accuracy: 0.9907 - val_loss: 0.0834 - val_accuracy: 0.9259
# Epoch 227/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0599 - accuracy: 0.9907 - val_loss: 0.0853 - val_accuracy: 0.9259
# Epoch 228/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0607 - accuracy: 0.9815 - val_loss: 0.0837 - val_accuracy: 0.9259
# Epoch 229/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0607 - accuracy: 0.9907 - val_loss: 0.0893 - val_accuracy: 0.9630
# Epoch 230/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0602 - accuracy: 0.9907 - val_loss: 0.0849 - val_accuracy: 0.9259
# Epoch 231/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0596 - accuracy: 0.9907 - val_loss: 0.0835 - val_accuracy: 0.9259
# Epoch 232/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0581 - accuracy: 0.9907 - val_loss: 0.0835 - val_accuracy: 0.9259
# Epoch 233/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0579 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 234/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0575 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 235/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0592 - accuracy: 0.9907 - val_loss: 0.0835 - val_accuracy: 0.9259
# Epoch 236/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0594 - accuracy: 0.9907 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 237/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0620 - accuracy: 0.9907 - val_loss: 0.0985 - val_accuracy: 0.9630
# Epoch 238/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0679 - accuracy: 0.9815 - val_loss: 0.0906 - val_accuracy: 0.9630
# Epoch 239/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0630 - accuracy: 0.9815 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 240/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0589 - accuracy: 0.9815 - val_loss: 0.0833 - val_accuracy: 0.9259
# Epoch 241/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0578 - accuracy: 0.9907 - val_loss: 0.0898 - val_accuracy: 0.9630
# Epoch 242/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0603 - accuracy: 0.9907 - val_loss: 0.0879 - val_accuracy: 0.9630
# Epoch 243/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0591 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 244/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0543 - accuracy: 0.9907 - val_loss: 0.0901 - val_accuracy: 0.9630
# Epoch 245/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0769 - accuracy: 0.9537 - val_loss: 0.0908 - val_accuracy: 0.9630
# Epoch 246/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0628 - accuracy: 0.9815 - val_loss: 0.0907 - val_accuracy: 0.9630
# Epoch 247/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0655 - accuracy: 0.9815 - val_loss: 0.1011 - val_accuracy: 0.9630
# Epoch 248/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0666 - accuracy: 0.9907 - val_loss: 0.0859 - val_accuracy: 0.9630
# Epoch 249/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0549 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 250/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0588 - accuracy: 0.9815 - val_loss: 0.0851 - val_accuracy: 0.9259
# Epoch 251/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0591 - accuracy: 0.9815 - val_loss: 0.0835 - val_accuracy: 0.9259
# Epoch 252/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0560 - accuracy: 0.9907 - val_loss: 0.0859 - val_accuracy: 0.9630
# Epoch 253/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0577 - accuracy: 0.9907 - val_loss: 0.0895 - val_accuracy: 0.9630
# Epoch 254/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0588 - accuracy: 0.9907 - val_loss: 0.0856 - val_accuracy: 0.9630
# Epoch 255/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0562 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 256/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0543 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9259
# Epoch 257/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0562 - accuracy: 0.9815 - val_loss: 0.0844 - val_accuracy: 0.9259
# Epoch 258/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0575 - accuracy: 0.9815 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 259/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0572 - accuracy: 0.9907 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 260/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0638 - accuracy: 0.9815 - val_loss: 0.0847 - val_accuracy: 0.9259
# Epoch 261/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0531 - accuracy: 0.9907 - val_loss: 0.0880 - val_accuracy: 0.9630
# Epoch 262/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0578 - accuracy: 0.9907 - val_loss: 0.0902 - val_accuracy: 0.9630
# Epoch 263/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0584 - accuracy: 0.9907 - val_loss: 0.0846 - val_accuracy: 0.9259
# Epoch 264/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0555 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 265/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0549 - accuracy: 0.9907 - val_loss: 0.0837 - val_accuracy: 0.9259
# Epoch 266/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0542 - accuracy: 0.9907 - val_loss: 0.0850 - val_accuracy: 0.9259
# Epoch 267/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0571 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 268/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0552 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 269/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0549 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 270/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0551 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 271/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0554 - accuracy: 0.9907 - val_loss: 0.0851 - val_accuracy: 0.9259
# Epoch 272/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0542 - accuracy: 0.9907 - val_loss: 0.0836 - val_accuracy: 0.9259
# Epoch 273/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0551 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 274/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0617 - accuracy: 0.9815 - val_loss: 0.0875 - val_accuracy: 0.9259
# Epoch 275/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0629 - accuracy: 0.9815 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 276/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0539 - accuracy: 0.9907 - val_loss: 0.0838 - val_accuracy: 0.9259
# Epoch 277/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0538 - accuracy: 0.9907 - val_loss: 0.0840 - val_accuracy: 0.9259
# Epoch 278/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0542 - accuracy: 0.9907 - val_loss: 0.0847 - val_accuracy: 0.9259
# Epoch 279/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0550 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 280/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0533 - accuracy: 0.9907 - val_loss: 0.0839 - val_accuracy: 0.9259
# Epoch 281/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0533 - accuracy: 0.9907 - val_loss: 0.0852 - val_accuracy: 0.9259
# Epoch 282/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0567 - accuracy: 0.9815 - val_loss: 0.0884 - val_accuracy: 0.9259
# Epoch 283/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0606 - accuracy: 0.9815 - val_loss: 0.0841 - val_accuracy: 0.9259
# Epoch 284/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0531 - accuracy: 0.9907 - val_loss: 0.0853 - val_accuracy: 0.9259
# Epoch 285/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0546 - accuracy: 0.9907 - val_loss: 0.0855 - val_accuracy: 0.9259
# Epoch 286/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0538 - accuracy: 0.9907 - val_loss: 0.0842 - val_accuracy: 0.9259
# Epoch 287/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0537 - accuracy: 0.9815 - val_loss: 0.0854 - val_accuracy: 0.9259
# Epoch 288/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0553 - accuracy: 0.9815 - val_loss: 0.0848 - val_accuracy: 0.9259
# Epoch 289/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0536 - accuracy: 0.9815 - val_loss: 0.0845 - val_accuracy: 0.9259
# Epoch 290/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0542 - accuracy: 0.9907 - val_loss: 0.0878 - val_accuracy: 0.9630

# %%
# 5. 모델 학습과정 시각화
fig, loss_ax = plt.subplots(figsize=(12,6))
loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
acc_ax = loss_ax.twinx()
acc_ax.plot(hist.history['accuracy'], 'g', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val accuracy')
loss_ax.set_xlabel('epochs')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(loc='center right')
acc_ax.legend()
plt.show()

# %% [markdown]
# # 2. sklearn 이용
# - 원핫인코딩을 하지 않고 라벨인코딩까지만 해야 작동. numpy배열

# %%
from sklearn.neural_network import MLPClassifier

# %%
# 머신러닝 3장 교안 43페이지 참조
mlp_model = MLPClassifier(hidden_layer_sizes=(50,30),
                     activation='relu',
                     solver='adam',
                     alpha=0.0001, # 과적합방지 강도
                     batch_size=40,
                     max_iter=1000, # epoch
                     early_stopping=True, # 조기종료 활성화(val_loss)
                     n_iter_no_change=50, # patience
                     warm_start=False, # True일 경우 이전학습에 이어서 학습
                     validation_fraction=0.1) # 검증셋 비율

# %%
mlp_model.fit(train_X, train_y)
# Out:
# MLPClassifier(batch_size=40, early_stopping=True, hidden_layer_sizes=(50, 30),
#               max_iter=1000, n_iter_no_change=50)

# %%
# 모델 평가 : accuracy(test_X, test_y), recall, precision(test_y, yhat)
from sklearn.metrics import recall_score, precision_score
accuracy = mlp_model.score(test_X, test_y)
yhat = mlp_model.predict(test_X)
recall = recall_score(test_y, yhat, average='weighted')
precision = precision_score(test_y, yhat, average='weighted')
print('정확도 :', accuracy)
print('재현율 :', recall)
print('정밀도 :', precision)
print('교차표\n', pd.crosstab(test_y, yhat,
                          rownames=['실제'],
                          colnames=['예측']))
# Out:
# 정확도 : 1.0
# 재현율 : 1.0
# 정밀도 : 1.0
# 교차표
#  예측  0  1  2
# 실제
# 0   5  0  0
# 1   0  5  0
# 2   0  0  5

# %% [markdown]
# # 3. 클래스를 이용

# %%
class DNNClassifier:
    @staticmethod
    def build(input_dim=4, activation='relu', optimizer='adam'):
        # model = Sequential()
        # model.add(Input(input_dim,))
        # model.add(Dense(50, activation=activation))
        # model.add(Dense(30, activation=activation))
        # model.add(Dense(3, activation='softmax'))
        model = Sequential([
            Input(input_dim,) ,
            Dense(50, activation=activation),
            Dense(30, activation=activation),
            Dense(3, activation='softmax')
        ])
        # 모델 학습 설정
        model.compile(loss='sparse_categorical_crossentropy',
                     optimizer=optimizer,
                     metrics=['accuracy'])
        return model

# %%
# %%time
# 모델
model = DNNClassifier.build(input_dim=4, activation='relu')
model.summary()
# 모델 학습
hist = model.fit(train_X, train_y,
                epochs=500,
                validation_split=0.2,
                verbose=0)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 50)                250
#
#  dense_19 (Dense)            (None, 30)                1530
#
#  dense_20 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# CPU times: total: 19.5 s
# Wall time: 15 s

# %%
loss, accuracy = model.evaluate(test_X, test_y)
loss, accuracy
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0384 - accuracy: 1.0000
# (0.03837354853749275, 1.0)

# %% [markdown]
# # 4. 함수형 API이용하기
# - 병렬처리 : 속도 높이려고
# - 레지듀얼블록(Residual block) : 모델의 성능을 높이려고(자연어처리, 이미지 처리)

# %%
# import
import numpy as np
from sklearn.model_selection import train_test_split # 데이터 분할(층화추출로)
from tensorflow.keras import Model # 모델 생성(입력층과 출력층을 이용)
from tensorflow.keras.layers import Dense, Dropout, add # add:레지듀얼블록
from tensorflow.keras.layers import concatenate # 병렬처리시
import matplotlib.pyplot as plt # 학습과정 시각화

# %%
from sklearn import datasets
iris = datasets.load_iris()
# iris.keys()
iris_X = iris.data
iris_y = iris.target # 라벨인코딩이 되어 있음
iris_X.shape, iris_y.shape
train_X, test_X, train_y, test_y = train_test_split(iris_X, iris_y,
                                                   test_size=0.1,
                                                   stratify=iris_y,
                                                   random_state=4)
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((135, 4), (135,), (15, 4), (15,))

# %%
# 기존의 model 스타일 4-> 50-> 30-> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=30, activation='relu')(dense1)
dense3 = Dense(units=3, activation='softmax')(dense2)
model = Model(inputs=input_, outputs=dense3)
model.summary()
model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=20,
         validation_split=0.2)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_9 (InputLayer)        [(None, 4)]               0
#
#  dense_24 (Dense)            (None, 50)                250
#
#  dense_25 (Dense)            (None, 30)                1530
#
#  dense_26 (Dense)            (None, 3)                 93
#
# =================================================================
# Total params: 1,873
# Trainable params: 1,873
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 4/4 [==============================] - 0s 58ms/step - loss: 1.1857 - accuracy: 0.3611 - val_loss: 1.3476 - val_accuracy: 0.2222
# Epoch 2/20
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0687 - accuracy: 0.3611 - val_loss: 1.1616 - val_accuracy: 0.2222
# Epoch 3/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9714 - accuracy: 0.3611 - val_loss: 1.0226 - val_accuracy: 0.2222
# Epoch 4/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9135 - accuracy: 0.4259 - val_loss: 0.9292 - val_accuracy: 0.7037
# Epoch 5/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.8822 - accuracy: 0.7593 - val_loss: 0.8636 - val_accuracy: 0.8519
# Epoch 6/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8540 - accuracy: 0.8519 - val_loss: 0.8158 - val_accuracy: 0.7778
# Epoch 7/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8214 - accuracy: 0.8796 - val_loss: 0.7754 - val_accuracy: 0.7778
# Epoch 8/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.7863 - accuracy: 0.8148 - val_loss: 0.7456 - val_accuracy: 0.7037
# Epoch 9/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7551 - accuracy: 0.7037 - val_loss: 0.7238 - val_accuracy: 0.7037
# Epoch 10/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.7288 - accuracy: 0.6667 - val_loss: 0.6958 - val_accuracy: 0.7037
# Epoch 11/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.7030 - accuracy: 0.6574 - val_loss: 0.6559 - val_accuracy: 0.7037
# Epoch 12/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6776 - accuracy: 0.6852 - val_loss: 0.6169 - val_accuracy: 0.7037
# Epoch 13/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.6533 - accuracy: 0.7778 - val_loss: 0.5853 - val_accuracy: 0.7778
# Epoch 14/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6304 - accuracy: 0.8519 - val_loss: 0.5618 - val_accuracy: 0.7778
# Epoch 15/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.6093 - accuracy: 0.8704 - val_loss: 0.5401 - val_accuracy: 0.7778
# Epoch 16/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.5891 - accuracy: 0.8611 - val_loss: 0.5224 - val_accuracy: 0.7778
# Epoch 17/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5722 - accuracy: 0.7963 - val_loss: 0.5068 - val_accuracy: 0.7407
# Epoch 18/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5546 - accuracy: 0.7963 - val_loss: 0.4863 - val_accuracy: 0.7778
# Epoch 19/20
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5387 - accuracy: 0.8611 - val_loss: 0.4686 - val_accuracy: 0.8148
# Epoch 20/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.5234 - accuracy: 0.8704 - val_loss: 0.4498 - val_accuracy: 0.8889

# %%
# 병렬처리
# 4 -> 160(50, 80, 30로 병렬처리) -> 32 -> 3
input_ = Input(shape=(4,))
dense1 = Dense(units=50, activation='relu')(input_)
dense2 = Dense(units=80, activation='relu')(input_)
dense3 = Dense(units=30, activation='relu')(input_)
x = concatenate([dense1, dense2, dense3])
# x = Dense(160, activation='relu')(input_)의 병렬처리
dense4 = Dense(32, activation='relu')(x)
output = Dense(3, activation='softmax')(dense4)
model = Model(inputs=input_, outputs= output)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 4)]          0           []
#
#  dense_30 (Dense)               (None, 50)           250         ['input_11[0][0]']
#
#  dense_31 (Dense)               (None, 80)           400         ['input_11[0][0]']
#
#  dense_32 (Dense)               (None, 30)           150         ['input_11[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 160)          0           ['dense_30[0][0]',
#                                                                   'dense_31[0][0]',
#                                                                   'dense_32[0][0]']
#
#  dense_33 (Dense)               (None, 32)           5152        ['concatenate_1[0][0]']
#
#  dense_34 (Dense)               (None, 3)            99          ['dense_33[0][0]']
#
# ==================================================================================================
# Total params: 6,051
# Trainable params: 6,051
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 레지듀얼블록(Residual Block): 딥러닝에서 딥한 네트워크가 학습이 잘 되지 않을 때
# 4 -> 50 -> 50 -> (레지듀얼) -> 3
input_ = Input(shape=(4,))
dense1 = Dense(50, activation='relu')(input_)
dense2 = Dense(50, activation='relu')(dense1)
dense3 = add([dense1, dense2])
output = Dense(3, activation='softmax')(dense3)
model = Model(inputs=input_, outputs=output)
model.summary()
model.compile(loss = 'sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
model.fit(train_X, train_y, epochs=500,
         validation_split=0.2, verbose=0)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 4)]          0           []
#
#  dense_35 (Dense)               (None, 50)           250         ['input_13[0][0]']
#
#  dense_36 (Dense)               (None, 50)           2550        ['dense_35[0][0]']
#
#  add (Add)                      (None, 50)           0           ['dense_35[0][0]',
#                                                                   'dense_36[0][0]']
#
#  dense_37 (Dense)               (None, 3)            153         ['add[0][0]']
#
# ==================================================================================================
# Total params: 2,953
# Trainable params: 2,953
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.evaluate(test_X, test_y)
# Out:
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0386 - accuracy: 1.0000
# [0.03859424591064453, 1.0]
